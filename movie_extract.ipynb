# %%
import pandas as pd

# %%
data_a = pd.read_csv("imdb_movies.csv")
# Out:
# D:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_a
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     12/26/1906
# 2                      Den sorte drøm  1911      8/19/1911
# 3                           Cleopatra  1912     11/13/1912
# ...

# %%
columns_a = data_a.columns
print(columns_a)
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
to_drop = ['original_title', 'date_published', 'director', 'writer',
       'production_company', 'actors', 'description', 'votes', 'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
       'reviews_from_users', 'reviews_from_critics']

# %%
data_a.drop(to_drop, inplace=True, axis=1)

# %%
data_a
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
df= data_a["genre"].str.split(",", expand=True)

# %%
df
# Out:
#                0         1         2
# 0        Romance      None      None
# 1      Biography     Crime     Drama
# 2          Drama      None      None
# 3          Drama   History      None
# 4      Adventure     Drama   Fantasy
# ...          ...       ...       ...
# 85850     Comedy      None      None
# 85851     Comedy     Drama      None
# 85852      Drama      None      None
# 85853      Drama    Family      None
# 85854      Drama      None      None
#
# [85855 rows x 3 columns]

# %%
new_df=data_a.join(df)

# %%
new_df
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
new_df=new_df.rename(columns={0: "genre_1", 1: "genre_2", 2: "genre_3" })

# %%
new_df
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
df= new_df["country"].str.split(",", n=5, expand=True)

# %%
data_a["country"].value_counts()
# Out:
# USA                                                                     28511
# India                                                                    6065
# UK                                                                       4111
# Japan                                                                    3077
# France                                                                   3055
#                                                                         ...
# Bosnia and Herzegovina, Republic of North Macedonia, Serbia, Croatia        1
# Germany, China, Spain, Luxembourg, France, Belgium, Brazil                  1
# Hong Kong, Macao                                                            1
# Italy, Romania, Bulgaria, Republic of North Macedonia                       1
# Italy, Colombia                                                             1
# Name: country, Length: 4907, dtype: int64

# %%
new_df=new_df.join(df)

# %%
new_df
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
new_df.drop(columns=5, inplace=True)

# %%
new_df
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
new_df[4].value_counts()
# Out:
#  USA        74
#  France     57
#  Germany    41
#  UK         31
#  Italy      23
#             ..
#  Armenia     1
#  Malta       1
#  Taiwan      1
#  Belarus     1
#  Chile       1
# Name: 4, Length: 82, dtype: int64

# %%
new_df=new_df.rename(columns={"year":"year_mv", 0: "country_1", 1: "country_2", 2: "country_3", 3: "country_4", 4: "country_5" })

# %%
new_df
# Out:
#       imdb_title_id                           title year_mv  \
# 0         tt0000009                      Miss Jerry    1894
# 1         tt0000574     The Story of the Kelly Gang    1906
# 2         tt0001892                  Den sorte drøm    1911
# 3         tt0002101                       Cleopatra    1912
# 4         tt0002130                       L'Inferno    1911
# ...             ...                             ...     ...
# 85850     tt9908390                         Le lion    2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard    2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu    2019
# 85853     tt9914286               Sokagin Çocuklari    2019
# 85854     tt9914942      La vida sense la Sara Amat    2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
lan_df= new_df["language"].str.split(",", n=4, expand=True)

# %%
lan_df
# Out:
#                0       1     2     3     4
# 0           None    None  None  None  None
# 1           None    None  None  None  None
# 2            NaN     NaN   NaN   NaN   NaN
# 3        English    None  None  None  None
# 4        Italian    None  None  None  None
# ...          ...     ...   ...   ...   ...
# 85850     French    None  None  None  None
# 85851     German   Dutch  None  None  None
# 85852  Malayalam    None  None  None  None
# 85853    Turkish    None  None  None  None
# 85854    Catalan    None  None  None  None
#
# [85855 rows x 5 columns]

# %%
movies_df=new_df.join(lan_df)

# %%
movies_df
# Out:
#       imdb_title_id                           title year_mv  \
# 0         tt0000009                      Miss Jerry    1894
# 1         tt0000574     The Story of the Kelly Gang    1906
# 2         tt0001892                  Den sorte drøm    1911
# 3         tt0002101                       Cleopatra    1912
# 4         tt0002130                       L'Inferno    1911
# ...             ...                             ...     ...
# 85850     tt9908390                         Le lion    2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard    2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu    2019
# 85853     tt9914286               Sokagin Çocuklari    2019
# 85854     tt9914942      La vida sense la Sara Amat    2019
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# ...

# %%
movies_df=movies_df.rename(columns={0: "lang_1", 1: "lang_2", 2: "lang_3", 3: "lang_4", 4: "lang_5" })

# %%
to_drop = ['genre','country','language']
movies_df.drop(to_drop, inplace=True, axis=1)

# %%
imdb_movies_info = movies_df
imdb_movies_info.head()
# Out:
#   imdb_title_id                        title year_mv  duration  avg_vote  \
# 0     tt0000009                   Miss Jerry    1894        45       5.9
# 1     tt0000574  The Story of the Kelly Gang    1906        70       6.1
# 2     tt0001892               Den sorte drøm    1911        53       5.8
# 3     tt0002101                    Cleopatra    1912       100       5.2
# 4     tt0002130                    L'Inferno    1911        68       7.0
#
#      genre_1   genre_2   genre_3  country_1 country_2 country_3 country_4  \
# 0    Romance      None      None        USA      None      None      None
# 1  Biography     Crime     Drama  Australia      None      None      None
# 2      Drama      None      None    Germany   Denmark      None      None
# 3      Drama   History      None        USA      None      None      None
# 4  Adventure     Drama   Fantasy      Italy      None      None      None
#
#   country_5   lang_1 lang_2 lang_3 lang_4 lang_5
# ...

# %%
imdb_movies_info.to_csv('movies_info.csv')

# %% [markdown]
# # Join Tables

# %%
#Open source
ratings = pd.read_csv("ratings.csv")

# %%
#Review variables
ratings.head(10)
# Out:
#    Unnamed: 0 imdb_title_id  avg_vote
# 0           0     tt0000009       5.9
# 1           1     tt0000574       6.1
# 2           2     tt0001892       5.8
# 3           3     tt0002101       5.2
# 4           4     tt0002130       7.0
# 5           5     tt0002199       5.7
# 6           6     tt0002423       6.8
# 7           7     tt0002445       6.2
# 8           8     tt0002452       6.7
# 9           9     tt0002461       5.5

# %%
#Drop Unnamed
ratings.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
ratings.drop(["a"], axis=1, inplace=True)

# %%
ratings.head(10)
# Out:
#   imdb_title_id  avg_vote
# 0     tt0000009       5.9
# 1     tt0000574       6.1
# 2     tt0001892       5.8
# 3     tt0002101       5.2
# 4     tt0002130       7.0
# 5     tt0002199       5.7
# 6     tt0002423       6.8
# 7     tt0002445       6.2
# 8     tt0002452       6.7
# 9     tt0002461       5.5

# %%
#Rename
ratings=ratings.rename(columns={"avg_vote": "avg_vote_2"})

# %%
#Outcome after rename
ratings.head(10)
# Out:
#   imdb_title_id  avg_vote_2
# 0     tt0000009         5.9
# 1     tt0000574         6.1
# 2     tt0001892         5.8
# 3     tt0002101         5.2
# 4     tt0002130         7.0
# 5     tt0002199         5.7
# 6     tt0002423         6.8
# 7     tt0002445         6.2
# 8     tt0002452         6.7
# 9     tt0002461         5.5

# %%
#Joining Dataframes
imdb_votes = new_df.join(ratings.set_index('imdb_title_id'), on='imdb_title_id')

# %%
#Join outcome
imdb_votes.head(10)
# Out:
#   imdb_title_id                                              title year_mv  \
# 0     tt0000009                                         Miss Jerry    1894
# 1     tt0000574                        The Story of the Kelly Gang    1906
# 2     tt0001892                                     Den sorte drøm    1911
# 3     tt0002101                                          Cleopatra    1912
# 4     tt0002130                                          L'Inferno    1911
# 5     tt0002199  From the Manger to the Cross; or, Jesus of Naz...    1912
# 6     tt0002423                                     Madame DuBarry    1919
# 7     tt0002445                                         Quo Vadis?    1913
# 8     tt0002452                              Independenta Romaniei    1912
# 9     tt0002461                                        Richard III    1912
#
#                        genre  duration           country language  avg_vote  \
# ...

# %%
#Saving CSV
imdb_votes.to_csv('global_IMDB.csv')
