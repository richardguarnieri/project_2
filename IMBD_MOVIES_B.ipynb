# %%
import pandas as pd

# %%
data_a = pd.read_csv("imdb_movies_b.csv")

# %%
data_a
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
columns_a = data_a.columns
print(columns_a)
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
to_drop = ['original_title', 'date_published', 'director', 'writer',
       'production_company', 'actors', 'description', 'votes', 'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
       'reviews_from_users', 'reviews_from_critics']

# %%
data_a.drop(to_drop, inplace=True, axis=1)

# %%
data_a
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 81268     tt9903716                                             Jessie  2019
# 81269     tt9905412                                              Ottam  2019
# 81270     tt9905462                                          Pengalila  2019
# 81271     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 81272     tt9914286                                  Sokagin Çocuklari  2019
#
# ...

# %%
df= data_a["genre"].str.split(",", expand=True)

# %%
df
# Out:
#                0          1         2
# 0      Biography      Crime     Drama
# 1          Drama       None      None
# 2          Drama    History      None
# 3      Adventure      Drama   Fantasy
# 4      Biography      Drama      None
# ...          ...        ...       ...
# 81268     Horror   Thriller      None
# 81269      Drama       None      None
# 81270      Drama       None      None
# 81271      Drama       None      None
# 81272      Drama     Family      None
#
# [81273 rows x 3 columns]

# %%
MoviesB_df=data_a.join(df)

# %%
MoviesB_df
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 81268     tt9903716                                             Jessie  2019
# 81269     tt9905412                                              Ottam  2019
# 81270     tt9905462                                          Pengalila  2019
# 81271     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 81272     tt9914286                                  Sokagin Çocuklari  2019
#
# ...

# %%
MoviesB_df=MoviesB_df.rename(columns={0: "genre_1", 1: "genre_2", 2: "genre_3" })

# %%
MoviesB_df
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 81268     tt9903716                                             Jessie  2019
# 81269     tt9905412                                              Ottam  2019
# 81270     tt9905462                                          Pengalila  2019
# 81271     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 81272     tt9914286                                  Sokagin Çocuklari  2019
#
# ...

# %%
df= MoviesB_df["country"].str.split(",", n=5, expand=True)

# %%
data_a["country"].value_counts()
# Out:
# USA                                       27490
# India                                      5540
# UK                                         3869
# France                                     2975
# Japan                                      2850
#                                           ...
# France, Romania, Portugal                     1
# Canada, Netherlands, Portugal, Finland        1
# France, Nigeria, USA, UK, Austria             1
# Sweden, Denmark, Argentina                    1
# UK, South Africa, USA, India                  1
# Name: country, Length: 4632, dtype: int64

# %%
MoviesB_df=MoviesB_df.join(df)

# %%
MoviesB_df
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 81268     tt9903716                                             Jessie  2019
# 81269     tt9905412                                              Ottam  2019
# 81270     tt9905462                                          Pengalila  2019
# 81271     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 81272     tt9914286                                  Sokagin Çocuklari  2019
#
# ...

# %%
MoviesB_df.drop(columns=5, inplace=True)

# %%
MoviesB_df
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 81268     tt9903716                                             Jessie  2019
# 81269     tt9905412                                              Ottam  2019
# 81270     tt9905462                                          Pengalila  2019
# 81271     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 81272     tt9914286                                  Sokagin Çocuklari  2019
#
# ...

# %%
MoviesB_df[4].value_counts()
# Out:
#  USA            65
#  France         54
#  Germany        41
#  UK             24
#  Netherlands    22
#                 ..
#  Angola          1
#  Yugoslavia      1
#  Kazakhstan      1
#  Taiwan          1
#  Serbia          1
# Name: 4, Length: 79, dtype: int64

# %%
MoviesB_df=MoviesB_df.rename(columns={"year":"year_mv", 0: "country_1", 1: "country_2", 2: "country_3", 3: "country_4", 4: "country_5" })

# %%
MoviesB_df
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#        year_mv                      genre  duration           country  \
# ...

# %%
lanB_df = MoviesB_df["language"].str.split(",", n=4, expand=True)

# %%
lanB_df
# Out:
#                0     1     2     3     4
# 0            NaN   NaN   NaN   NaN   NaN
# 1            NaN   NaN   NaN   NaN   NaN
# 2        English  None  None  None  None
# 3        Italian  None  None  None  None
# 4        English  None  None  None  None
# ...          ...   ...   ...   ...   ...
# 81268     Telugu  None  None  None  None
# 81269  Malayalam  None  None  None  None
# 81270  Malayalam  None  None  None  None
# 81271  Malayalam  None  None  None  None
# 81272    Turkish  None  None  None  None
#
# [81273 rows x 5 columns]

# %%
movieB_df = MoviesB_df.join(lanB_df)

# %%
movieB_df
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#        year_mv                      genre  duration           country  \
# ...

# %%
movieB_df=movieB_df.rename(columns={0: "lang_1", 1: "lang_2", 2: "lang_3", 3: "lang_4", 4: "lang_5" })

# %%
movieB_df
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#        year_mv                      genre  duration           country  \
# ...

# %%
to_drop = ['genre','country','language']
movieB_df.drop(to_drop, inplace=True, axis=1)

# %%
imdb_movies_b = movieB_df
imdb_movies_b.head()
# Out:
#   imdb_title_id                                              title  year_mv  \
# 0     tt0000574                        The Story of the Kelly Gang     1906
# 1     tt0001892                                     Den sorte drøm     1911
# 2     tt0002101                                          Cleopatra     1912
# 3     tt0002130                                          L'Inferno     1911
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...     1912
#
#    duration  avg_vote    genre_1   genre_2   genre_3  country_1 country_2  \
# 0        70       6.1  Biography     Crime     Drama  Australia      None
# 1        53       5.9      Drama      None      None    Germany   Denmark
# 2       100       5.2      Drama   History      None        USA      None
# 3        68       7.0  Adventure     Drama   Fantasy      Italy      None
# 4        60       5.7  Biography     Drama      None        USA      None
#
# ...

# %%
imdb_movies_b.to_csv('movies_info_b.csv')
